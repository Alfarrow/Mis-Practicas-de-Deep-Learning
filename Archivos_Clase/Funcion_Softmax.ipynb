# %%
import numpy as np

# %%
y = [3.2,1.3,0.2,0.8]
print(y)
# Out:
# [3.2, 1.3, 0.2, 0.8]

# %%
n = np.exp(y)
sum_n = sum(n)
Sy = []

for m in range(len(n)):
  Sy.append(round(n[m]/sum_n,3))

print(Sy)
# Out:
# [0.775, 0.116, 0.039, 0.07]
